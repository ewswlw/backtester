# %%
import warnings
import numpy as np
import pandas as pd
from pathlib import Path
import os
import vectorbt as vbt
import io
import sys
from contextlib import redirect_stdout
from datetime import datetime
import math
import plotly.graph_objects as go
from plotly.subplots import make_subplots

import warnings
warnings.filterwarnings('ignore')

# Add project root to path
project_root = Path().absolute().parent
sys.path.append(str(project_root))

# Import utils with different aliases
from src.utils import csv_exporter as csv_utils
from src.utils import validation as val_utils
from src.utils import transformations as trans_utils
from src.utils import data_merger as merge_utils
from src.utils import config_validator as config_utils
from src.utils import metrics as metric_utils
from src.core.bloomberg_fetcher import fetch_bloomberg_data
from src.utils.transformations import get_ohlc

# %%
# Getting all the data 
mapping = {
    ('I05510CA Index', 'INDEX_OAS_TSY_BP'): 'cad_oas',
    ('LF98TRUU Index', 'INDEX_OAS_TSY_BP'): 'us_hy_oas',
    ('LUACTRUU Index', 'INDEX_OAS_TSY_BP'): 'us_ig_oas',
    ('SPTSX Index', 'PX_LAST'): 'tsx',
    ('VIX Index', 'PX_LAST'): 'vix',
}

# Calculate dates
end_date = datetime.now().strftime('%Y-%m-%d')
start_date ='2002-01-01'

# Fetch the data
df = fetch_bloomberg_data(
    mapping=mapping,
    start_date=start_date,
    end_date=end_date,
    periodicity='D',
    align_start=True
).dropna()

# Getting all the er_ytd data 
mapping1 = {
    ('I05510CA Index', 'INDEX_EXCESS_RETURN_YTD'): 'cad_ig_er',
    ('LF98TRUU Index', 'INDEX_EXCESS_RETURN_YTD'): 'us_hy_er',
    ('LUACTRUU Index', 'INDEX_EXCESS_RETURN_YTD'): 'us_ig_er',
}

# Fetch the er_ytd_data
df1 = fetch_bloomberg_data(
    mapping=mapping1,
    start_date=start_date,
    end_date=end_date,
    periodicity='D',
    align_start=True
).dropna()

# Convert er_ytd data to an index
df2 = trans_utils.convert_er_ytd_to_index(df1[['cad_ig_er','us_hy_er','us_ig_er']])
final_df = merge_utils.merge_dfs(df, df2, fill='ffill', start_date_align='yes')

# Handle bad data point for cad_oas on Nov 15 2005
bad_date = '2005-11-15'
if bad_date in final_df.index:
    final_df.loc[bad_date, 'cad_oas'] = final_df.loc[final_df.index < bad_date, 'cad_oas'].iloc[-1]

def calculate_qtd_changes(df):
    df_copy = df.copy()
    df_copy.index = pd.to_datetime(df_copy.index)
    
    qtd_changes = pd.DataFrame(index=df_copy.index)
    for col in df_copy.columns:
        changes = []
        for date in df_copy.index:
            # Get the start of the current quarter
            current_quarter_start = date.to_period('Q').start_time
            
            # Get the end of previous quarter (last day of previous quarter)
            prev_quarter_end = current_quarter_start - pd.Timedelta(days=1)
            
            # Get the value at the end of previous quarter
            mask = df_copy.index <= prev_quarter_end
            if not mask.any():
                changes.append(np.nan)
                continue
            
            prev_quarter_value = df_copy[col][mask].iloc[-1]
            current_value = df_copy[col][date]
            
            # Calculate change
            pct_change = (current_value / prev_quarter_value - 1) * 100
            changes.append(pct_change)
            
        qtd_changes[f'{col}_qtd'] = changes
    return qtd_changes

def calculate_ytd_changes(df):
    df_copy = df.copy()
    df_copy.index = pd.to_datetime(df_copy.index)
    
    ytd_changes = pd.DataFrame(index=df_copy.index)
    for col in df_copy.columns:
        changes = []
        for date in df_copy.index:
            # Get the start of the current year
            current_year_start = date.to_period('Y').start_time
            
            # Get the end of previous year (last day of previous year)
            prev_year_end = current_year_start - pd.Timedelta(days=1)
            
            # Get the value at the end of previous year
            mask = df_copy.index <= prev_year_end
            if not mask.any():
                changes.append(np.nan)
                continue
            
            prev_year_value = df_copy[col][mask].iloc[-1]
            current_value = df_copy[col][date]
            
            # Calculate change
            pct_change = (current_value / prev_year_value - 1) * 100
            changes.append(pct_change)
            
        ytd_changes[f'{col}_ytd'] = changes
    return ytd_changes

def add_all_changes(df):
    # Make a copy to avoid modifying original
    result_df = df.copy()
    result_df.index = pd.to_datetime(result_df.index)
    
    # Calculate regular percentage changes (3M and 1YR)
    for col in df.columns:
        # 3-month change (63 trading days approximation)
        result_df[f'{col}_3m'] = df[col].pct_change(periods=63) * 100
        # 1-year change (252 trading days approximation)
        result_df[f'{col}_1yr'] = df[col].pct_change(periods=252) * 100
    
    # Add QTD and YTD changes
    qtd_df = calculate_qtd_changes(df)
    ytd_df = calculate_ytd_changes(df)
    
    # Combine all changes
    for col in qtd_df.columns:
        result_df[col] = qtd_df[col]
    for col in ytd_df.columns:
        result_df[col] = ytd_df[col]
    
    # Drop any rows with missing values
    result_df = result_df.dropna()
    
    return result_df

def verify_calculations(df, n_random_samples=5):
    """Comprehensive verification of calculations"""
    print("Running verification checks...")
    print("\n1. Random Date Samples:")
    print("=" * 80)
    
    # Get random dates
    random_dates = df.sample(n=n_random_samples).index.sort_values()
    
    for date in random_dates:
        date = pd.to_datetime(date)
        
        # Get period boundaries
        current_quarter_start = date.to_period('Q').start_time
        current_year_start = date.to_period('Y').start_time
        prev_quarter_end = current_quarter_start - pd.Timedelta(days=1)
        prev_year_end = current_year_start - pd.Timedelta(days=1)
        
        print(f"\nDate: {date.strftime('%Y-%m-%d')}")
        print(f"Previous Quarter End: {prev_quarter_end.strftime('%Y-%m-%d')}")
        print(f"Previous Year End: {prev_year_end.strftime('%Y-%m-%d')}")
        
        # Check calculations for TSX
        col = 'tsx'
        current_value = df[col][date]
        prev_quarter_value = df[df.index <= prev_quarter_end][col].iloc[-1]
        prev_year_value = df[df.index <= prev_year_end][col].iloc[-1]
        
        manual_qtd = (current_value / prev_quarter_value - 1) * 100
        manual_ytd = (current_value / prev_year_value - 1) * 100
        
        print(f"\nTSX Values:")
        print(f"Current: {current_value:.2f}")
        print(f"Prev Quarter End: {prev_quarter_value:.2f}")
        print(f"Prev Year End: {prev_year_value:.2f}")
        print(f"QTD% (Manual): {manual_qtd:.2f}%")
        print(f"QTD% (Calculated): {df[f'{col}_qtd'][date]:.2f}%")
        print(f"YTD% (Manual): {manual_ytd:.2f}%")
        print(f"YTD% (Calculated): {df[f'{col}_ytd'][date]:.2f}%")
        
        # Check for significant differences
        qtd_diff = abs(manual_qtd - df[f'{col}_qtd'][date])
        ytd_diff = abs(manual_ytd - df[f'{col}_ytd'][date])
        
        if qtd_diff > 0.01:
            print(f"WARNING: Large QTD difference ({qtd_diff:.4f}%)")
        if ytd_diff > 0.01:
            print(f"WARNING: Large YTD difference ({ytd_diff:.4f}%)")
            
    print("\n2. Quarter/Year Boundary Checks:")
    print("=" * 80)
    
    # Find dates near quarter/year boundaries
    quarter_starts = df.index[pd.to_datetime(df.index).is_quarter_start]
    year_starts = df.index[pd.to_datetime(df.index).is_year_start]
    
    if len(quarter_starts) > 0:
        print("\nFirst day of quarter example:")
        first_quarter_date = quarter_starts[len(quarter_starts)//2]  # Take a middle example
        print(f"Date: {first_quarter_date}")
        print(f"TSX QTD%: {df.loc[first_quarter_date, 'tsx_qtd']:.2f}%")
        
    if len(year_starts) > 0:
        print("\nFirst day of year example:")
        first_year_date = year_starts[len(year_starts)//2]  # Take a middle example
        print(f"Date: {first_year_date}")
        print(f"TSX YTD%: {df.loc[first_year_date, 'tsx_ytd']:.2f}%")

# Calculate all changes
print("Calculating changes...")
final_df = add_all_changes(final_df)

# Run comprehensive verification
print("\nRunning verification...")
verify_calculations(final_df)

# Show basic info about the final dataset
print("\nFinal Dataset Info:")
print("=" * 80)
final_df.info()
# Out:
# Calculating changes...
#
# Running verification...
# Running verification checks...
#
# 1. Random Date Samples:
# ================================================================================
#
# Date: 2006-04-20
# Previous Quarter End: 2006-03-31
# Previous Year End: 2005-12-31
#
# TSX Values:
# Current: 12313.66
# Prev Quarter End: 12110.61
# Prev Year End: 11272.26
# QTD% (Manual): 1.68%
# QTD% (Calculated): 1.68%
# YTD% (Manual): 9.24%
# YTD% (Calculated): 9.24%
#
# Date: 2007-12-10
# Previous Quarter End: 2007-09-30
# Previous Year End: 2006-12-31
#
# TSX Values:
# Current: 13940.36
# Prev Quarter End: 14098.89
# Prev Year End: 12908.39
# QTD% (Manual): -1.12%
# QTD% (Calculated): -1.12%
# YTD% (Manual): 7.99%
# YTD% (Calculated): 7.99%
#
# Date: 2014-05-26
# Previous Quarter End: 2014-03-31
# Previous Year End: 2013-12-31
#
# TSX Values:
# Current: 14715.69
# Prev Quarter End: 14335.31
# Prev Year End: 13621.55
# QTD% (Manual): 2.65%
# QTD% (Calculated): 2.65%
# YTD% (Manual): 8.03%
# YTD% (Calculated): 8.03%
#
# Date: 2018-11-01
# Previous Quarter End: 2018-09-30
# Previous Year End: 2017-12-31
#
# TSX Values:
# Current: 15150.15
# Prev Quarter End: 16073.14
# Prev Year End: 16209.13
# QTD% (Manual): -5.74%
# QTD% (Calculated): -5.74%
# YTD% (Manual): -6.53%
# YTD% (Calculated): -6.53%
#
# Date: 2024-09-20
# Previous Quarter End: 2024-06-30
# Previous Year End: 2023-12-31
#
# TSX Values:
# Current: 23867.37
# Prev Quarter End: 21875.79
# Prev Year End: 20958.44
# QTD% (Manual): 9.10%
# QTD% (Calculated): 9.10%
# YTD% (Manual): 13.88%
# YTD% (Calculated): 13.88%
#
# 2. Quarter/Year Boundary Checks:
# ================================================================================
#
# First day of quarter example:
# Date: 2014-04-01 00:00:00
# TSX QTD%: 0.32%
#
# Final Dataset Info:
# ================================================================================
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5491 entries, 2003-09-24 to 2025-01-29
# Data columns (total 40 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   cad_oas              5491 non-null   float64
#  1   us_hy_oas            5491 non-null   float64
#  2   us_ig_oas            5491 non-null   float64
#  3   tsx                  5491 non-null   float64
#  4   vix                  5491 non-null   float64
#  5   cad_ig_er_index      5491 non-null   float64
#  6   us_hy_er_index       5491 non-null   float64
#  7   us_ig_er_index       5491 non-null   float64
#  8   cad_oas_3m           5491 non-null   float64
#  9   cad_oas_1yr          5491 non-null   float64
#  10  us_hy_oas_3m         5491 non-null   float64
#  11  us_hy_oas_1yr        5491 non-null   float64
#  12  us_ig_oas_3m         5491 non-null   float64
#  13  us_ig_oas_1yr        5491 non-null   float64
#  14  tsx_3m               5491 non-null   float64
#  15  tsx_1yr              5491 non-null   float64
#  16  vix_3m               5491 non-null   float64
#  17  vix_1yr              5491 non-null   float64
#  18  cad_ig_er_index_3m   5491 non-null   float64
#  19  cad_ig_er_index_1yr  5491 non-null   float64
#  20  us_hy_er_index_3m    5491 non-null   float64
#  21  us_hy_er_index_1yr   5491 non-null   float64
#  22  us_ig_er_index_3m    5491 non-null   float64
#  23  us_ig_er_index_1yr   5491 non-null   float64
#  24  cad_oas_qtd          5491 non-null   float64
#  25  us_hy_oas_qtd        5491 non-null   float64
#  26  us_ig_oas_qtd        5491 non-null   float64
#  27  tsx_qtd              5491 non-null   float64
#  28  vix_qtd              5491 non-null   float64
#  29  cad_ig_er_index_qtd  5491 non-null   float64
#  30  us_hy_er_index_qtd   5491 non-null   float64
#  31  us_ig_er_index_qtd   5491 non-null   float64
#  32  cad_oas_ytd          5491 non-null   float64
#  33  us_hy_oas_ytd        5491 non-null   float64
#  34  us_ig_oas_ytd        5491 non-null   float64
#  35  tsx_ytd              5491 non-null   float64
#  36  vix_ytd              5491 non-null   float64
#  37  cad_ig_er_index_ytd  5491 non-null   float64
#  38  us_hy_er_index_ytd   5491 non-null   float64
#  39  us_ig_er_index_ytd   5491 non-null   float64
# dtypes: float64(40)
# memory usage: 1.8 MB

# %%
import vectorbt as vbt
from vectorbt.portfolio.enums import SizeType

# Create signals based on CAD OAS QTD being negative
signals = final_df['cad_oas_qtd'] < 0

# Create portfolio for our strategy
strategy_pf = vbt.Portfolio.from_signals(
    final_df['cad_ig_er_index'],
    entries=signals,
    exits=~signals,
    freq='1D',
    init_cash=100000,
    size=1.0,
    size_type=SizeType.Percent,
    accumulate=False
)

# Create buy & hold portfolio for comparison
bh_pf = vbt.Portfolio.from_holding(
    final_df['cad_ig_er_index'],
    freq='1D',
    init_cash=100000,
    size=1.0,
    size_type=SizeType.Percent
)

# Compare performance metrics
print("\nStrategy Performance:")
print(strategy_pf.stats())
print("\nBuy & Hold Performance:")
print(bh_pf.stats())
# Out:
# Strategy Performance:
# Start                               2003-09-24 00:00:00
# End                                 2025-01-29 00:00:00
# Period                               5491 days 00:00:00
# Start Value                                    100000.0
# End Value                                 162043.853315
# Total Return [%]                              62.043853
# Benchmark Return [%]                          31.869219
# Max Gross Exposure [%]                            100.0
# Total Fees Paid                                     0.0
# Max Drawdown [%]                               1.967439
# Max Drawdown Duration                 508 days 00:00:00
# Total Trades                                        169
# Total Closed Trades                                 169
# Total Open Trades                                     0
# Open Trade PnL                                      0.0
# Win Rate [%]                                  59.171598
# Best Trade [%]                                 7.069267
# Worst Trade [%]                                -0.43424
# Avg Winning Trade [%]                          0.544884
# Avg Losing Trade [%]                          -0.079848
# Avg Winning Trade Duration             27 days 01:12:00
# Avg Losing Trade Duration     5 days 02:05:13.043478260
# Profit Factor                                 10.254785
# Expectancy                                   367.123392
# Sharpe Ratio                                   2.983816
# Calmar Ratio                                   1.657298
# Omega Ratio                                    2.102171
# Sortino Ratio                                  5.424231
# dtype: object
#
# Buy & Hold Performance:
# Start                         2003-09-24 00:00:00
# End                           2025-01-29 00:00:00
# Period                         5491 days 00:00:00
# Start Value                              100000.0
# End Value                           131869.218758
# Total Return [%]                        31.869219
# Benchmark Return [%]                    31.869219
# Max Gross Exposure [%]                      100.0
# Total Fees Paid                               0.0
# Max Drawdown [%]                        15.481159
# Max Drawdown Duration          1005 days 00:00:00
# Total Trades                                    1
# Total Closed Trades                             0
# Total Open Trades                               1
# Open Trade PnL                       31869.218758
# Win Rate [%]                                  NaN
# Best Trade [%]                                NaN
# Worst Trade [%]                               NaN
# Avg Winning Trade [%]                         NaN
# Avg Losing Trade [%]                          NaN
# Avg Winning Trade Duration                    NaT
# Avg Losing Trade Duration                     NaT
# Profit Factor                                 NaN
# Expectancy                                    NaN
# Sharpe Ratio                             1.031519
# Calmar Ratio                             0.119882
# Omega Ratio                              1.225886
# Sortino Ratio                             1.36184
# Name: cad_ig_er_index, dtype: object

# %%
import vectorbt as vbt
from vectorbt.portfolio.enums import SizeType

# Create signals based on CAD OAS YTD being negative
signals = final_df['cad_oas_ytd'] < 0

# Create portfolio for our strategy
strategy_pf = vbt.Portfolio.from_signals(
    final_df['cad_ig_er_index'],
    entries=signals,
    exits=~signals,
    freq='1D',
    init_cash=100000,
    size=1.0,
    size_type=SizeType.Percent,
    accumulate=False
)

# Create buy & hold portfolio for comparison
bh_pf = vbt.Portfolio.from_holding(
    final_df['cad_ig_er_index'],
    freq='1D',
    init_cash=100000,
    size=1.0,
    size_type=SizeType.Percent
)

# Compare performance metrics
print("\nStrategy Performance:")
print(strategy_pf.stats())
print("\nBuy & Hold Performance:")
print(bh_pf.stats())
# Out:
# Strategy Performance:
# Start                                2003-09-24 00:00:00
# End                                  2025-01-29 00:00:00
# Period                                5491 days 00:00:00
# Start Value                                     100000.0
# End Value                                  154744.803811
# Total Return [%]                               54.744804
# Benchmark Return [%]                           31.869219
# Max Gross Exposure [%]                             100.0
# Total Fees Paid                                      0.0
# Max Drawdown [%]                                1.839838
# Max Drawdown Duration                  485 days 00:00:00
# Total Trades                                          83
# Total Closed Trades                                   83
# Total Open Trades                                      0
# Open Trade PnL                                       0.0
# Win Rate [%]                                   68.674699
# Best Trade [%]                                 16.083912
# Worst Trade [%]                                -0.189953
# Avg Winning Trade [%]                           0.818268
# Avg Losing Trade [%]                           -0.050321
# Avg Winning Trade Duration    52 days 23:34:44.210526316
# Avg Losing Trade Duration     11 days 16:36:55.384615384
# Profit Factor                                  36.960005
# Expectancy                                     659.57595
# Sharpe Ratio                                    2.899619
# Calmar Ratio                                    1.600553
# Omega Ratio                                     1.944367
# Sortino Ratio                                   5.000812
# dtype: object
#
# Buy & Hold Performance:
# Start                         2003-09-24 00:00:00
# End                           2025-01-29 00:00:00
# Period                         5491 days 00:00:00
# Start Value                              100000.0
# End Value                           131869.218758
# Total Return [%]                        31.869219
# Benchmark Return [%]                    31.869219
# Max Gross Exposure [%]                      100.0
# Total Fees Paid                               0.0
# Max Drawdown [%]                        15.481159
# Max Drawdown Duration          1005 days 00:00:00
# Total Trades                                    1
# Total Closed Trades                             0
# Total Open Trades                               1
# Open Trade PnL                       31869.218758
# Win Rate [%]                                  NaN
# Best Trade [%]                                NaN
# Worst Trade [%]                               NaN
# Avg Winning Trade [%]                         NaN
# Avg Losing Trade [%]                          NaN
# Avg Winning Trade Duration                    NaT
# Avg Losing Trade Duration                     NaT
# Profit Factor                                 NaN
# Expectancy                                    NaN
# Sharpe Ratio                             1.031519
# Calmar Ratio                             0.119882
# Omega Ratio                              1.225886
# Sortino Ratio                             1.36184
# Name: cad_ig_er_index, dtype: object

# %%
import vectorbt as vbt
from vectorbt.portfolio.enums import SizeType

# Create signals based on both CAD OAS QTD and YTD being negative
signals = (final_df['cad_oas_qtd'] < 0) & (final_df['cad_oas_ytd'] < 0)

# Create portfolio for our strategy
strategy_pf = vbt.Portfolio.from_signals(
    final_df['cad_ig_er_index'],
    entries=signals,
    exits=~signals,
    freq='1D',
    init_cash=100000,
    size=1.0,
    size_type=SizeType.Percent,
    accumulate=False
)

# Create buy & hold portfolio for comparison
bh_pf = vbt.Portfolio.from_holding(
    final_df['cad_ig_er_index'],
    freq='1D',
    init_cash=100000,
    size=1.0,
    size_type=SizeType.Percent
)

# Compare performance metrics
print("\nStrategy Performance:")
print(strategy_pf.stats())
print("\nBuy & Hold Performance:")
print(bh_pf.stats())
# Out:
# Strategy Performance:
# Start                                2003-09-24 00:00:00
# End                                  2025-01-29 00:00:00
# Period                                5491 days 00:00:00
# Start Value                                     100000.0
# End Value                                  146422.127425
# Total Return [%]                               46.422127
# Benchmark Return [%]                           31.869219
# Max Gross Exposure [%]                             100.0
# Total Fees Paid                                      0.0
# Max Drawdown [%]                                1.839838
# Max Drawdown Duration                  509 days 00:00:00
# Total Trades                                         150
# Total Closed Trades                                  150
# Total Open Trades                                      0
# Open Trade PnL                                       0.0
# Win Rate [%]                                   57.333333
# Best Trade [%]                                  7.069267
# Worst Trade [%]                                -0.336925
# Avg Winning Trade [%]                           0.494261
# Avg Losing Trade [%]                           -0.060544
# Avg Winning Trade Duration    26 days 07:15:20.930232558
# Avg Losing Trade Duration                4 days 06:00:00
# Profit Factor                                  10.897867
# Expectancy                                    309.480849
# Sharpe Ratio                                    2.779795
# Calmar Ratio                                    1.395312
# Omega Ratio                                     2.128167
# Sortino Ratio                                   4.949761
# dtype: object
#
# Buy & Hold Performance:
# Start                         2003-09-24 00:00:00
# End                           2025-01-29 00:00:00
# Period                         5491 days 00:00:00
# Start Value                              100000.0
# End Value                           131869.218758
# Total Return [%]                        31.869219
# Benchmark Return [%]                    31.869219
# Max Gross Exposure [%]                      100.0
# Total Fees Paid                               0.0
# Max Drawdown [%]                        15.481159
# Max Drawdown Duration          1005 days 00:00:00
# Total Trades                                    1
# Total Closed Trades                             0
# Total Open Trades                               1
# Open Trade PnL                       31869.218758
# Win Rate [%]                                  NaN
# Best Trade [%]                                NaN
# Worst Trade [%]                               NaN
# Avg Winning Trade [%]                         NaN
# Avg Losing Trade [%]                          NaN
# Avg Winning Trade Duration                    NaT
# Avg Losing Trade Duration                     NaT
# Profit Factor                                 NaN
# Expectancy                                    NaN
# Sharpe Ratio                             1.031519
# Calmar Ratio                             0.119882
# Omega Ratio                              1.225886
# Sortino Ratio                             1.36184
# Name: cad_ig_er_index, dtype: object

# %%
import vectorbt as vbt
from vectorbt.portfolio.enums import SizeType

# Create signals based on either CAD OAS QTD or YTD being negative
signals = (final_df['cad_oas_qtd'] < 0) | (final_df['cad_oas_ytd'] < 0)

# Create portfolio for our strategy
strategy_pf = vbt.Portfolio.from_signals(
    final_df['cad_ig_er_index'],
    entries=signals,
    exits=~signals,
    freq='1D',
    init_cash=100000,
    size=1.0,
    size_type=SizeType.Percent,
    accumulate=False
)

# Create buy & hold portfolio for comparison
bh_pf = vbt.Portfolio.from_holding(
    final_df['cad_ig_er_index'],
    freq='1D',
    init_cash=100000,
    size=1.0,
    size_type=SizeType.Percent
)

# Compare performance metrics
print("\nStrategy Performance:")
print(strategy_pf.stats())
print("\nBuy & Hold Performance:")
print(bh_pf.stats())
# Out:
# Strategy Performance:
# Start                         2003-09-24 00:00:00
# End                           2025-01-29 00:00:00
# Period                         5491 days 00:00:00
# Start Value                              100000.0
# End Value                           171254.473153
# Total Return [%]                        71.254473
# Benchmark Return [%]                    31.869219
# Max Gross Exposure [%]                      100.0
# Total Fees Paid                               0.0
# Max Drawdown [%]                         1.839838
# Max Drawdown Duration           405 days 00:00:00
# Total Trades                                  102
# Total Closed Trades                           102
# Total Open Trades                               0
# Open Trade PnL                                0.0
# Win Rate [%]                            70.588235
# Best Trade [%]                          16.083912
# Worst Trade [%]                          -0.43424
# Avg Winning Trade [%]                    0.811917
# Avg Losing Trade [%]                    -0.092335
# Avg Winning Trade Duration       48 days 05:20:00
# Avg Losing Trade Duration        12 days 11:12:00
# Profit Factor                           22.626127
# Expectancy                             698.573266
# Sharpe Ratio                             3.106354
# Calmar Ratio                             1.978868
# Omega Ratio                              1.956809
# Sortino Ratio                            5.488925
# dtype: object
#
# Buy & Hold Performance:
# Start                         2003-09-24 00:00:00
# End                           2025-01-29 00:00:00
# Period                         5491 days 00:00:00
# Start Value                              100000.0
# End Value                           131869.218758
# Total Return [%]                        31.869219
# Benchmark Return [%]                    31.869219
# Max Gross Exposure [%]                      100.0
# Total Fees Paid                               0.0
# Max Drawdown [%]                        15.481159
# Max Drawdown Duration          1005 days 00:00:00
# Total Trades                                    1
# Total Closed Trades                             0
# Total Open Trades                               1
# Open Trade PnL                       31869.218758
# Win Rate [%]                                  NaN
# Best Trade [%]                                NaN
# Worst Trade [%]                               NaN
# Avg Winning Trade [%]                         NaN
# Avg Losing Trade [%]                          NaN
# Avg Winning Trade Duration                    NaT
# Avg Losing Trade Duration                     NaT
# Profit Factor                                 NaN
# Expectancy                                    NaN
# Sharpe Ratio                             1.031519
# Calmar Ratio                             0.119882
# Omega Ratio                              1.225886
# Sortino Ratio                             1.36184
# Name: cad_ig_er_index, dtype: object

# %%
import vectorbt as vbt
from vectorbt.portfolio.enums import SizeType
import pandas as pd

# Define our indicators and their types
positive_indicators = ['cad_ig_er_index', 'us_hy_er_index', 'us_ig_er_index', 'tsx']
negative_indicators = ['cad_oas', 'us_hy_oas', 'us_ig_oas', 'vix']
intervals = ['3m', '1yr', 'qtd', 'ytd']

# Dictionary to store all portfolios
portfolios = {}

# Create strategies for positive indicators
for indicator in positive_indicators:
    for interval in intervals:
        col_name = f'{indicator}_{interval}'
        strategy_name = f'{indicator}_{interval}_pos'
        signals = final_df[col_name] > 0
        
        portfolios[strategy_name] = vbt.Portfolio.from_signals(
            final_df['cad_ig_er_index'],
            entries=signals,
            exits=~signals,
            freq='1D',
            init_cash=100000,
            size=1.0,
            size_type=SizeType.Percent,
            accumulate=False
        )

# Create strategies for negative indicators
for indicator in negative_indicators:
    for interval in intervals:
        col_name = f'{indicator}_{interval}'
        strategy_name = f'{indicator}_{interval}_neg'
        signals = final_df[col_name] < 0
        
        portfolios[strategy_name] = vbt.Portfolio.from_signals(
            final_df['cad_ig_er_index'],
            entries=signals,
            exits=~signals,
            freq='1D',
            init_cash=100000,
            size=1.0,
            size_type=SizeType.Percent,
            accumulate=False
        )

# Create buy & hold portfolio for comparison
bh_pf = vbt.Portfolio.from_holding(
    final_df['cad_ig_er_index'],
    freq='1D',
    init_cash=100000,
    size=1.0,
    size_type=SizeType.Percent
)
portfolios['buy_and_hold'] = bh_pf

# Create a comparison DataFrame
stats_list = []
for name, pf in portfolios.items():
    stats = pf.stats()
    stats_list.append(pd.Series(stats, name=name))

comparison_df = pd.DataFrame(stats_list)

# Display results
print("\nStrategy Comparison:")
print(comparison_df)
# Out:
# Strategy Comparison:
#                              Start        End    Period  Start Value  \
# cad_ig_er_index_3m_pos  2003-09-24 2025-01-29 5491 days     100000.0
# cad_ig_er_index_1yr_pos 2003-09-24 2025-01-29 5491 days     100000.0
# cad_ig_er_index_qtd_pos 2003-09-24 2025-01-29 5491 days     100000.0
# cad_ig_er_index_ytd_pos 2003-09-24 2025-01-29 5491 days     100000.0
# us_hy_er_index_3m_pos   2003-09-24 2025-01-29 5491 days     100000.0
# us_hy_er_index_1yr_pos  2003-09-24 2025-01-29 5491 days     100000.0
# us_hy_er_index_qtd_pos  2003-09-24 2025-01-29 5491 days     100000.0
# us_hy_er_index_ytd_pos  2003-09-24 2025-01-29 5491 days     100000.0
# us_ig_er_index_3m_pos   2003-09-24 2025-01-29 5491 days     100000.0
# us_ig_er_index_1yr_pos  2003-09-24 2025-01-29 5491 days     100000.0
# us_ig_er_index_qtd_pos  2003-09-24 2025-01-29 5491 days     100000.0
# us_ig_er_index_ytd_pos  2003-09-24 2025-01-29 5491 days     100000.0
# tsx_3m_pos              2003-09-24 2025-01-29 5491 days     100000.0
# tsx_1yr_pos             2003-09-24 2025-01-29 5491 days     100000.0
# tsx_qtd_pos             2003-09-24 2025-01-29 5491 days     100000.0
# tsx_ytd_pos             2003-09-24 2025-01-29 5491 days     100000.0
# cad_oas_3m_neg          2003-09-24 2025-01-29 5491 days     100000.0
# cad_oas_1yr_neg         2003-09-24 2025-01-29 5491 days     100000.0
# cad_oas_qtd_neg         2003-09-24 2025-01-29 5491 days     100000.0
# cad_oas_ytd_neg         2003-09-24 2025-01-29 5491 days     100000.0
# us_hy_oas_3m_neg        2003-09-24 2025-01-29 5491 days     100000.0
# us_hy_oas_1yr_neg       2003-09-24 2025-01-29 5491 days     100000.0
# us_hy_oas_qtd_neg       2003-09-24 2025-01-29 5491 days     100000.0
# us_hy_oas_ytd_neg       2003-09-24 2025-01-29 5491 days     100000.0
# us_ig_oas_3m_neg        2003-09-24 2025-01-29 5491 days     100000.0
# us_ig_oas_1yr_neg       2003-09-24 2025-01-29 5491 days     100000.0
# us_ig_oas_qtd_neg       2003-09-24 2025-01-29 5491 days     100000.0
# us_ig_oas_ytd_neg       2003-09-24 2025-01-29 5491 days     100000.0
# vix_3m_neg              2003-09-24 2025-01-29 5491 days     100000.0
# vix_1yr_neg             2003-09-24 2025-01-29 5491 days     100000.0
# vix_qtd_neg             2003-09-24 2025-01-29 5491 days     100000.0
# vix_ytd_neg             2003-09-24 2025-01-29 5491 days     100000.0
# buy_and_hold            2003-09-24 2025-01-29 5491 days     100000.0
#
#                              End Value  Total Return [%]  \
# cad_ig_er_index_3m_pos   153165.691727         53.165692
# cad_ig_er_index_1yr_pos  128688.650643         28.688651
# cad_ig_er_index_qtd_pos  172831.518489         72.831518
# cad_ig_er_index_ytd_pos  157684.851058         57.684851
# us_hy_er_index_3m_pos    163967.660150         63.967660
# us_hy_er_index_1yr_pos   131103.098058         31.103098
# us_hy_er_index_qtd_pos   183820.471091         83.820471
# us_hy_er_index_ytd_pos   158844.157484         58.844157
# us_ig_er_index_3m_pos    163179.174410         63.179174
# us_ig_er_index_1yr_pos   131158.826043         31.158826
# us_ig_er_index_qtd_pos   181286.578967         81.286579
# us_ig_er_index_ytd_pos   157254.568763         57.254569
# tsx_3m_pos               163207.004985         63.207005
# tsx_1yr_pos              119954.237826         19.954238
# tsx_qtd_pos              179980.578829         79.980579
# tsx_ytd_pos              155371.475326         55.371475
# cad_oas_3m_neg           151329.823947         51.329824
# cad_oas_1yr_neg          123808.718891         23.808719
# cad_oas_qtd_neg          162043.853315         62.043853
# cad_oas_ytd_neg          154744.803811         54.744804
# us_hy_oas_3m_neg         160139.093081         60.139093
# us_hy_oas_1yr_neg        128475.484262         28.475484
# us_hy_oas_qtd_neg        177760.512920         77.760513
# us_hy_oas_ytd_neg        159282.925859         59.282926
# us_ig_oas_3m_neg         163086.990477         63.086990
# us_ig_oas_1yr_neg        132878.730636         32.878731
# us_ig_oas_qtd_neg        183121.928350         83.121928
# us_ig_oas_ytd_neg        155924.879840         55.924880
# vix_3m_neg               168765.108131         68.765108
# vix_1yr_neg              137428.861218         37.428861
# vix_qtd_neg              176851.332529         76.851333
# vix_ytd_neg              160464.045020         60.464045
# buy_and_hold             131869.218758         31.869219
#
#                          Benchmark Return [%]  Max Gross Exposure [%]  \
# cad_ig_er_index_3m_pos              31.869219                   100.0
# cad_ig_er_index_1yr_pos             31.869219                   100.0
# cad_ig_er_index_qtd_pos             31.869219                   100.0
# cad_ig_er_index_ytd_pos             31.869219                   100.0
# us_hy_er_index_3m_pos               31.869219                   100.0
# us_hy_er_index_1yr_pos              31.869219                   100.0
# us_hy_er_index_qtd_pos              31.869219                   100.0
# us_hy_er_index_ytd_pos              31.869219                   100.0
# us_ig_er_index_3m_pos               31.869219                   100.0
# us_ig_er_index_1yr_pos              31.869219                   100.0
# us_ig_er_index_qtd_pos              31.869219                   100.0
# us_ig_er_index_ytd_pos              31.869219                   100.0
# tsx_3m_pos                          31.869219                   100.0
# tsx_1yr_pos                         31.869219                   100.0
# tsx_qtd_pos                         31.869219                   100.0
# tsx_ytd_pos                         31.869219                   100.0
# cad_oas_3m_neg                      31.869219                   100.0
# cad_oas_1yr_neg                     31.869219                   100.0
# cad_oas_qtd_neg                     31.869219                   100.0
# cad_oas_ytd_neg                     31.869219                   100.0
# us_hy_oas_3m_neg                    31.869219                   100.0
# us_hy_oas_1yr_neg                   31.869219                   100.0
# us_hy_oas_qtd_neg                   31.869219                   100.0
# us_hy_oas_ytd_neg                   31.869219                   100.0
# us_ig_oas_3m_neg                    31.869219                   100.0
# us_ig_oas_1yr_neg                   31.869219                   100.0
# us_ig_oas_qtd_neg                   31.869219                   100.0
# us_ig_oas_ytd_neg                   31.869219                   100.0
# vix_3m_neg                          31.869219                   100.0
# vix_1yr_neg                         31.869219                   100.0
# vix_qtd_neg                         31.869219                   100.0
# vix_ytd_neg                         31.869219                   100.0
# buy_and_hold                        31.869219                   100.0
#
#                          Total Fees Paid  Max Drawdown [%]  ...  \
# cad_ig_er_index_3m_pos               0.0          1.601274  ...
# cad_ig_er_index_1yr_pos              0.0          3.929956  ...
# cad_ig_er_index_qtd_pos              0.0          1.839838  ...
# cad_ig_er_index_ytd_pos              0.0          1.890074  ...
# us_hy_er_index_3m_pos                0.0          2.175584  ...
# us_hy_er_index_1yr_pos               0.0          2.402191  ...
# us_hy_er_index_qtd_pos               0.0          1.839838  ...
# us_hy_er_index_ytd_pos               0.0          1.929941  ...
# us_ig_er_index_3m_pos                0.0          2.309203  ...
# us_ig_er_index_1yr_pos               0.0          2.402191  ...
# us_ig_er_index_qtd_pos               0.0          1.839838  ...
# us_ig_er_index_ytd_pos               0.0          1.839838  ...
# tsx_3m_pos                           0.0          2.815608  ...
# tsx_1yr_pos                          0.0          6.563281  ...
# tsx_qtd_pos                          0.0          2.194076  ...
# tsx_ytd_pos                          0.0          4.468584  ...
# cad_oas_3m_neg                       0.0          1.654301  ...
# cad_oas_1yr_neg                      0.0          2.598070  ...
# cad_oas_qtd_neg                      0.0          1.967439  ...
# cad_oas_ytd_neg                      0.0          1.839838  ...
# us_hy_oas_3m_neg                     0.0          1.839838  ...
# us_hy_oas_1yr_neg                    0.0          2.402191  ...
# us_hy_oas_qtd_neg                    0.0          1.712487  ...
# us_hy_oas_ytd_neg                    0.0          1.712487  ...
# us_ig_oas_3m_neg                     0.0          2.218917  ...
# us_ig_oas_1yr_neg                    0.0          2.402191  ...
# us_ig_oas_qtd_neg                    0.0          1.839838  ...
# us_ig_oas_ytd_neg                    0.0          1.839838  ...
# vix_3m_neg                           0.0          1.891928  ...
# vix_1yr_neg                          0.0          1.626081  ...
# vix_qtd_neg                          0.0          1.738030  ...
# vix_ytd_neg                          0.0          1.603420  ...
# buy_and_hold                         0.0         15.481159  ...
#
#                         Avg Winning Trade [%]  Avg Losing Trade [%]  \
# cad_ig_er_index_3m_pos               1.654524             -0.110793
# cad_ig_er_index_1yr_pos              2.436330             -0.295799
# cad_ig_er_index_qtd_pos              1.641569             -0.071180
# cad_ig_er_index_ytd_pos              4.133754             -0.053823
# us_hy_er_index_3m_pos                1.064890             -0.131043
# us_hy_er_index_1yr_pos               1.267298             -0.174864
# us_hy_er_index_qtd_pos               0.880377             -0.112995
# us_hy_er_index_ytd_pos               1.940347             -0.186566
# us_ig_er_index_3m_pos                1.225746             -0.108311
# us_ig_er_index_1yr_pos               1.575651             -0.147755
# us_ig_er_index_qtd_pos               0.827649             -0.118995
# us_ig_er_index_ytd_pos               1.496997             -0.177658
# tsx_3m_pos                           0.629104             -0.203919
# tsx_1yr_pos                          0.655071             -0.343743
# tsx_qtd_pos                          0.529106             -0.119544
# tsx_ytd_pos                          0.882059             -0.307516
# cad_oas_3m_neg                       0.587665             -0.066678
# cad_oas_1yr_neg                      0.642180             -0.146466
# cad_oas_qtd_neg                      0.544884             -0.079848
# cad_oas_ytd_neg                      0.818268             -0.050321
# us_hy_oas_3m_neg                     0.863113             -0.097738
# us_hy_oas_1yr_neg                    1.075576             -0.129979
# us_hy_oas_qtd_neg                    0.627817             -0.077330
# us_hy_oas_ytd_neg                    1.080524             -0.123703
# us_ig_oas_3m_neg                     0.960973             -0.106093
# us_ig_oas_1yr_neg                    0.992613             -0.039550
# us_ig_oas_qtd_neg                    0.887037             -0.113730
# us_ig_oas_ytd_neg                    1.556662             -0.164753
# vix_3m_neg                           0.344771             -0.105660
# vix_1yr_neg                          0.311317             -0.097605
# vix_qtd_neg                          0.354523             -0.108747
# vix_ytd_neg                          0.501476             -0.124401
# buy_and_hold                              NaN                   NaN
#
#                          Avg Winning Trade Duration  \
# cad_ig_er_index_3m_pos            120 days 18:00:00
# cad_ig_er_index_1yr_pos           344 days 10:40:00
# cad_ig_er_index_qtd_pos  87 days 11:01:37.297297297
# cad_ig_er_index_ytd_pos 301 days 13:05:27.272727276
# us_hy_er_index_3m_pos              70 days 22:00:00
# us_hy_er_index_1yr_pos  157 days 08:50:31.578947370
# us_hy_er_index_qtd_pos   46 days 07:47:01.621621621
# us_hy_er_index_ytd_pos  130 days 13:50:46.153846152
# us_ig_er_index_3m_pos              83 days 00:00:00
# us_ig_er_index_1yr_pos  202 days 08:34:17.142857144
# us_ig_er_index_qtd_pos   46 days 06:09:13.846153846
# us_ig_er_index_ytd_pos  103 days 17:27:16.363636364
# tsx_3m_pos               36 days 12:08:16.551724138
# tsx_1yr_pos              63 days 20:21:49.090909091
# tsx_qtd_pos              26 days 06:14:38.048780488
# tsx_ytd_pos                        58 days 21:36:00
# cad_oas_3m_neg           34 days 10:44:12.631578947
# cad_oas_1yr_neg          70 days 13:09:40.645161290
# cad_oas_qtd_neg                    27 days 01:12:00
# cad_oas_ytd_neg          52 days 23:34:44.210526316
# us_hy_oas_3m_neg         52 days 09:55:51.724137931
# us_hy_oas_1yr_neg       117 days 14:36:31.304347826
# us_hy_oas_qtd_neg                  32 days 00:30:00
# us_hy_oas_ytd_neg                  71 days 12:48:00
# us_ig_oas_3m_neg                   58 days 01:46:40
# us_ig_oas_1yr_neg                 109 days 10:00:00
# us_ig_oas_qtd_neg        45 days 01:38:37.808219178
# us_ig_oas_ytd_neg       101 days 20:54:11.612903226
# vix_3m_neg               14 days 22:32:29.171270718
# vix_1yr_neg                        22 days 13:12:00
# vix_qtd_neg              15 days 00:15:49.450549450
# vix_ytd_neg                        26 days 17:46:40
# buy_and_hold                                    NaT
#
#                          Avg Losing Trade Duration  Profit Factor  \
# cad_ig_er_index_3m_pos   8 days 18:09:43.783783783      11.569585
# cad_ig_er_index_1yr_pos           52 days 21:36:00       7.094467
# cad_ig_er_index_qtd_pos            9 days 01:12:00      10.881703
# cad_ig_er_index_ytd_pos           21 days 02:00:00      33.182312
# us_hy_er_index_3m_pos             27 days 04:30:00      23.765925
# us_hy_er_index_1yr_pos  33 days 10:17:08.571428571       9.707303
# us_hy_er_index_qtd_pos  13 days 01:50:46.153846153      15.584712
# us_hy_er_index_ytd_pos  17 days 05:32:18.461538461      10.228731
# us_ig_er_index_3m_pos    8 days 11:17:38.823529411      27.200784
# us_ig_er_index_1yr_pos            41 days 15:00:00      19.172203
# us_ig_er_index_qtd_pos             7 days 00:48:00      19.955508
# us_ig_er_index_ytd_pos            11 days 04:48:00      20.114540
# tsx_3m_pos               9 days 06:32:43.636363636       8.583568
# tsx_1yr_pos             91 days 18:39:59.999999999       3.486307
# tsx_qtd_pos              8 days 14:05:13.043478260      12.387090
# tsx_ytd_pos                       15 days 17:00:00       7.656186
# cad_oas_3m_neg           4 days 16:56:28.235294117      13.022492
# cad_oas_1yr_neg                   13 days 01:55:12       5.327594
# cad_oas_qtd_neg          5 days 02:05:13.043478260      10.254785
# cad_oas_ytd_neg         11 days 16:36:55.384615384      36.960005
# us_hy_oas_3m_neg         6 days 16:27:25.714285714      14.231621
# us_hy_oas_1yr_neg                 41 days 14:24:00      19.212340
# us_hy_oas_qtd_neg        7 days 16:44:39.069767441      20.321075
# us_hy_oas_ytd_neg       10 days 08:28:14.117647058      24.520389
# us_ig_oas_3m_neg         6 days 02:49:24.705882352      28.473839
# us_ig_oas_1yr_neg        4 days 10:17:08.571428571      80.445940
# us_ig_oas_qtd_neg        8 days 07:18:15.652173913      27.165879
# us_ig_oas_ytd_neg                  9 days 04:00:00      23.707667
# vix_3m_neg               4 days 16:39:31.764705882       7.056258
# vix_1yr_neg                        6 days 00:00:00       7.378139
# vix_qtd_neg              6 days 12:46:27.096774193      10.057460
# vix_ytd_neg                        5 days 22:56:00       9.902149
# buy_and_hold                                   NaT            NaN
#
#                           Expectancy  Sharpe Ratio  Calmar Ratio  Omega Ratio  \
# cad_ig_er_index_3m_pos    774.274446      2.818646      1.795192     1.787654
# cad_ig_er_index_1yr_pos  1067.234188      1.496656      0.430218     1.380457
# cad_ig_er_index_qtd_pos   603.380717      3.126465      2.013203     1.932176
# cad_ig_er_index_ytd_pos  1506.810510      2.733176      1.626196     1.748034
# us_hy_er_index_3m_pos     950.317942      3.166685      1.535990     1.915079
# us_hy_er_index_1yr_pos    715.079208      1.797056      0.756170     1.439218
# us_hy_er_index_qtd_pos    721.255421      3.362146      2.244637     2.072221
# us_hy_er_index_ytd_pos   1050.317512      2.806546      1.618615     1.773627
# us_ig_er_index_3m_pos    1037.527969      3.118780      1.432774     1.972873
# us_ig_er_index_1yr_pos   1032.249610      1.945854      0.757368     1.496213
# us_ig_er_index_qtd_pos    753.308072      3.390660      2.192440     2.115510
# us_ig_er_index_ytd_pos   1194.081047      2.911450      1.660424     1.871280
# tsx_3m_pos                493.244065      3.306462      1.175497     2.017211
# tsx_1yr_pos               306.393962      1.074022      0.185386     1.264544
# tsx_qtd_pos               469.987866      3.445004      1.815683     2.177365
# tsx_ytd_pos               648.059607      2.746371      0.665181     1.761304
# cad_oas_3m_neg            381.519426      2.966568      1.687822     2.035470
# cad_oas_1yr_neg           306.838379      1.757167      0.550316     1.495727
# cad_oas_qtd_neg           367.123392      2.983816      1.657298     2.102171
# cad_oas_ytd_neg           659.575950      2.899619      1.600553     1.944367
# us_hy_oas_3m_neg          609.405674      3.128071      1.728143     2.039621
# us_hy_oas_1yr_neg         782.068757      2.054609      0.699167     1.547201
# us_hy_oas_qtd_neg         536.664436      3.314392      2.276217     2.160047
# us_hy_oas_ytd_neg         911.809956      3.003033      1.835193     1.965851
# us_ig_oas_3m_neg          889.444878      3.207742      1.489324     2.113607
# us_ig_oas_1yr_neg         838.718154      2.280445      0.794090     1.645028
# us_ig_oas_qtd_neg         866.597258      3.441681      2.230315     2.225671
# us_ig_oas_ytd_neg        1301.992623      2.916066      1.628816     1.964244
# vix_3m_neg                255.103854      3.349638      1.871090     2.238476
# vix_1yr_neg               215.108398      2.713673      1.313520     1.800658
# vix_qtd_neg               313.120326      3.588387      2.222392     2.393237
# vix_ytd_neg               395.189837      3.463792      1.991622     2.199539
# buy_and_hold                     NaN      1.031519      0.119882     1.225886
#
#                          Sortino Ratio
# cad_ig_er_index_3m_pos        4.642629
# cad_ig_er_index_1yr_pos       1.923511
# cad_ig_er_index_qtd_pos       5.513243
# cad_ig_er_index_ytd_pos       4.441632
# us_hy_er_index_3m_pos         5.305449
# us_hy_er_index_1yr_pos        2.574995
# us_hy_er_index_qtd_pos        6.055618
# us_hy_er_index_ytd_pos        4.609103
# us_ig_er_index_3m_pos         5.310150
# us_ig_er_index_1yr_pos        2.679724
# us_ig_er_index_qtd_pos        6.139432
# us_ig_er_index_ytd_pos        4.872177
# tsx_3m_pos                    5.621098
# tsx_1yr_pos                   1.355273
# tsx_qtd_pos                   6.350416
# tsx_ytd_pos                   4.402548
# cad_oas_3m_neg                5.159440
# cad_oas_1yr_neg               2.431429
# cad_oas_qtd_neg               5.424231
# cad_oas_ytd_neg               5.000812
# us_hy_oas_3m_neg              5.315429
# us_hy_oas_1yr_neg             2.970066
# us_hy_oas_qtd_neg             6.022168
# us_hy_oas_ytd_neg             5.144117
# us_ig_oas_3m_neg              5.589496
# us_ig_oas_1yr_neg             3.351566
# us_ig_oas_qtd_neg             6.361970
# us_ig_oas_ytd_neg             5.019535
# vix_3m_neg                    6.146994
# vix_1yr_neg                   4.275191
# vix_qtd_neg                   7.311140
# vix_ytd_neg                   6.606063
# buy_and_hold                  1.361840
#
# [33 rows x 28 columns]

# %%
import vectorbt as vbt
from vectorbt.portfolio.enums import SizeType
import pandas as pd
import numpy as np
from deap import base, creator, tools, algorithms
import random
import warnings
warnings.filterwarnings('ignore')

# Clear any existing DEAP types
if 'FitnessMax' in creator.__dict__:
    del creator.FitnessMax
if 'Individual' in creator.__dict__:
    del creator.Individual

# Define our indicators and their types
positive_indicators = ['cad_ig_er_index', 'us_hy_er_index', 'us_ig_er_index', 'tsx']
negative_indicators = ['cad_oas', 'us_hy_oas', 'us_ig_oas', 'vix']
intervals = ['3m', '1yr', 'qtd', 'ytd']

# Print data information
print("\nData Overview:")
print(f"final_df shape: {final_df.shape}")
print(f"final_df columns: {final_df.columns.tolist()}")
print(f"final_df index: {final_df.index[0]} to {final_df.index[-1]}")

# Vectorized signal generation
def generate_signals(indicators, intervals, final_df, condition_func):
    signals = {}
    for indicator in indicators:
        for interval in intervals:
            col_name = f'{indicator}_{interval}'
            if col_name not in final_df.columns:
                print(f"Warning: Column {col_name} not found in DataFrame")
                continue
                
            signal_name = f'{indicator}_{interval}_{condition_func.__name__}'
            signal_value = condition_func(final_df[col_name])
            signals[signal_name] = signal_value
            
            print(f"\nGenerating signal for {signal_name}:")
            print(f"Signal True values: {signal_value.sum()}")
            print(f"Signal False values: {(~signal_value).sum()}")
    return signals

# Generate signals using vectorized operations
print("\nGenerating positive signals...")
positive_signals = generate_signals(positive_indicators, intervals, final_df, lambda x: x > 0)
print("\nGenerating negative signals...")
negative_signals = generate_signals(negative_indicators, intervals, final_df, lambda x: x < 0)
signal_dict = {**positive_signals, **negative_signals}

# Convert to numpy arrays for faster operations
signal_names = list(signal_dict.keys())
signals = np.array([signal_dict[name].values for name in signal_names])

print("\nSignal Generation Summary:")
print(f"Number of signals generated: {len(signal_names)}")
print(f"Signal array shape: {signals.shape}")

# Dictionary to store all portfolios
all_portfolios = {}

def evaluate(individual):
    used_signals = set()
    operations = []
    combined_signal = None
    
    # Count active signals for debugging
    active_signals = sum(1 for i in range(len(signals)) if individual[i * 2])
    if active_signals < 2:
        return -np.inf,
    
    for i in range(len(signals)):
        if individual[i * 2]:  # If signal is used
            signal = signals[i]
            signal_name = signal_names[i]
            
            if signal_name in used_signals:
                continue
                
            used_signals.add(signal_name)
            
            if combined_signal is None:
                combined_signal = signal
            else:
                op_idx = i * 2 - 1
                if op_idx < len(individual):
                    operation = "OR" if individual[op_idx] else "AND"
                    operations.append(operation)
                    
                    if operation == "OR":
                        combined_signal = combined_signal | signal
                    else:
                        combined_signal = combined_signal & signal
    
    if combined_signal is None or len(used_signals) < 2:
        return -np.inf,
    
    try:
        # Convert combined signal to pandas Series with proper index
        combined_signal = pd.Series(combined_signal, index=final_df.index)
        
        # Create portfolio
        pf = vbt.Portfolio.from_signals(
            close=final_df['cad_ig_er_index'],
            entries=combined_signal,
            exits=~combined_signal,
            freq='1D',
            init_cash=100000,
            size=1.0,
            size_type=SizeType.Percent,
            accumulate=False
        )
        
        # Calculate total return
        total_return = pf.total_return()
        
        if not np.isfinite(total_return):
            return -np.inf,
            
        # Store successful portfolio
        strategy_key = "Combined:" + ":".join(used_signals)
        operations_str = ":".join(operations)
        key = f"{strategy_key}:{operations_str}"
        all_portfolios[key] = pf
        
        return float(total_return),
        
    except Exception as e:
        print(f"Error in evaluate function: {str(e)}")
        return -np.inf,

# Genetic Algorithm Setup
creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("Individual", list, fitness=creator.FitnessMax)

def create_diverse_individual():
    ind = [0] * n_bits
    n_signals_to_use = random.randint(2, 4)
    signal_positions = random.sample(range(n_signals), n_signals_to_use)
    
    for pos in signal_positions:
        ind[pos * 2] = 1
        if pos > 0:
            ind[pos * 2 - 1] = random.randint(0, 1)
    
    return creator.Individual(ind)

# Initialize genetic algorithm
toolbox = base.Toolbox()
n_signals = len(signals)
n_bits = 2 * n_signals - 1

toolbox.register("individual", create_diverse_individual)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)
toolbox.register("evaluate", evaluate)
toolbox.register("mate", tools.cxTwoPoint)
toolbox.register("mutate", tools.mutFlipBit, indpb=0.3)  # Increased mutation rate
toolbox.register("select", tools.selTournament, tournsize=3)

# GA Parameters
POPULATION_SIZE = 50
MAX_GENERATIONS = 30
HALL_OF_FAME_SIZE = 10

# Create hall of fame
hall_of_fame = tools.HallOfFame(HALL_OF_FAME_SIZE)

# Initialize population
population = toolbox.population(n=POPULATION_SIZE)

# Run genetic algorithm
print("\nStarting genetic algorithm optimization...")
best_fitness = -np.inf
best_individual = None

for gen in range(MAX_GENERATIONS):
    # Generate offspring
    offspring = algorithms.varAnd(population, toolbox, cxpb=0.7, mutpb=0.3)
    
    # Evaluate individuals
    fits = map(toolbox.evaluate, offspring)
    for fit, ind in zip(fits, offspring):
        ind.fitness.values = fit
        
        # Update best individual
        if fit[0] > best_fitness:
            best_fitness = fit[0]
            best_individual = ind.copy()
    
    # Select next generation
    population = toolbox.select(offspring, len(population))
    
    # Update hall of fame
    hall_of_fame.update(population)
    
    # Print progress
    gen_fits = [ind.fitness.values[0] for ind in population]
    gen_best = max(gen_fits)
    print(f"Generation {gen}: Best Fitness = {gen_best:.4f}, Overall Best = {best_fitness:.4f}")
    
    # Early stopping if we find a good solution
    if best_fitness > 0.5:  # 50% return
        print(f"Found good solution at generation {gen}")
        break

print("\nOptimization completed.")

# Process results
if all_portfolios:
    # Create results DataFrame with debugging
    all_results = []
    print("\nProcessing portfolios...")
    
    for name, pf in all_portfolios.items():
        try:
            # Get metrics with percentage formatting
            total_return = float(pf.total_return()) * 100  # Convert to percentage
            sharpe = float(pf.sharpe_ratio())
            max_dd = float(pf.max_drawdown()) * 100  # Convert to percentage
            
            result = {
                'Strategy': name,
                'Total_Return_%': total_return,
                'Sharpe_Ratio': sharpe,
                'Max_Drawdown_%': max_dd
            }
            
            print(f"\nProcessed {name}:")
            print(f"Total Return: {total_return:.2f}%")
            print(f"Sharpe Ratio: {sharpe:.2f}")
            print(f"Max Drawdown: {max_dd:.2f}%")
            
            all_results.append(result)
            
        except Exception as e:
            print(f"Error processing portfolio {name}: {str(e)}")
            continue

    if all_results:
        # Create and sort results DataFrame
        results_df = pd.DataFrame(all_results)
        results_df = results_df.sort_values('Total_Return_%', ascending=False)

        print("\nTop 10 Strategies Overall:")
        print(results_df.head(10))

        # Get best strategy
        best_strategy_name = results_df.iloc[0]['Strategy']
        best_portfolio = all_portfolios[best_strategy_name]

        # Create buy & hold portfolio for comparison
        bh_pf = vbt.Portfolio.from_holding(
            final_df['cad_ig_er_index'],
            freq='1D',
            init_cash=100000,
            size=1.0,
            size_type=SizeType.Percent
        )

        print("\nBest Strategy:", best_strategy_name)
        print("\nBest Strategy Performance:")
        print(f"Total Return: {best_portfolio.total_return():.2%}")
        print(f"Sharpe Ratio: {best_portfolio.sharpe_ratio():.2f}")
        print(f"Max Drawdown: {best_portfolio.max_drawdown():.2%}")

        print("\nBuy & Hold Performance:")
        print(f"Total Return: {bh_pf.total_return():.2%}")
        print(f"Sharpe Ratio: {bh_pf.sharpe_ratio():.2f}")
        print(f"Max Drawdown: {bh_pf.max_drawdown():.2%}")

        # Save best strategy signals for analysis
        if best_individual is not None:
            print("\nBest Strategy Signal Composition:")
            used_signals = []
            for i in range(len(signals)):
                if best_individual[i * 2]:
                    used_signals.append(signal_names[i])
            print("Signals used:", used_signals)
    else:
        print("No valid results were processed.")
else:
    print("No valid strategies were found.")
# Out:
# Data Overview:
# final_df shape: (5491, 40)
# final_df columns: ['cad_oas', 'us_hy_oas', 'us_ig_oas', 'tsx', 'vix', 'cad_ig_er_index', 'us_hy_er_index', 'us_ig_er_index', 'cad_oas_3m', 'cad_oas_1yr', 'us_hy_oas_3m', 'us_hy_oas_1yr', 'us_ig_oas_3m', 'us_ig_oas_1yr', 'tsx_3m', 'tsx_1yr', 'vix_3m', 'vix_1yr', 'cad_ig_er_index_3m', 'cad_ig_er_index_1yr', 'us_hy_er_index_3m', 'us_hy_er_index_1yr', 'us_ig_er_index_3m', 'us_ig_er_index_1yr', 'cad_oas_qtd', 'us_hy_oas_qtd', 'us_ig_oas_qtd', 'tsx_qtd', 'vix_qtd', 'cad_ig_er_index_qtd', 'us_hy_er_index_qtd', 'us_ig_er_index_qtd', 'cad_oas_ytd', 'us_hy_oas_ytd', 'us_ig_oas_ytd', 'tsx_ytd', 'vix_ytd', 'cad_ig_er_index_ytd', 'us_hy_er_index_ytd', 'us_ig_er_index_ytd']
# final_df index: 2003-09-24 00:00:00 to 2025-01-29 00:00:00
#
# Generating positive signals...
#
# Generating signal for cad_ig_er_index_3m_<lambda>:
# Signal True values: 3804
# Signal False values: 1687
#
# Generating signal for cad_ig_er_index_1yr_<lambda>:
# Signal True values: 4110
# Signal False values: 1381
#
# Generating signal for cad_ig_er_index_qtd_<lambda>:
# Signal True values: 4045
# Signal False values: 1446
#
# Generating signal for cad_ig_er_index_ytd_<lambda>:
# Signal True values: 4095
# Signal False values: 1396
#
# Generating signal for us_hy_er_index_3m_<lambda>:
# Signal True values: 3958
# Signal False values: 1533
#
# Generating signal for us_hy_er_index_1yr_<lambda>:
# Signal True values: 3925
# Signal False values: 1566
#
# Generating signal for us_hy_er_index_qtd_<lambda>:
# Signal True values: 4022
# Signal False values: 1469
#
# Generating signal for us_hy_er_index_ytd_<lambda>:
# Signal True values: 4101
# Signal False values: 1390
#
# Generating signal for us_ig_er_index_3m_<lambda>:
# Signal True values: 3645
# Signal False values: 1846
#
# Generating signal for us_ig_er_index_1yr_<lambda>:
# Signal True values: 3644
# Signal False values: 1847
#
# Generating signal for us_ig_er_index_qtd_<lambda>:
# Signal True values: 3830
# Signal False values: 1661
#
# Generating signal for us_ig_er_index_ytd_<lambda>:
# Signal True values: 3602
# Signal False values: 1889
#
# Generating signal for tsx_3m_<lambda>:
# Signal True values: 3606
# Signal False values: 1885
#
# Generating signal for tsx_1yr_<lambda>:
# Signal True values: 4029
# Signal False values: 1462
#
# Generating signal for tsx_qtd_<lambda>:
# Signal True values: 3637
# Signal False values: 1854
#
# Generating signal for tsx_ytd_<lambda>:
# Signal True values: 3923
# Signal False values: 1568
#
# Generating negative signals...
#
# Generating signal for cad_oas_3m_<lambda>:
# Signal True values: 2953
# Signal False values: 2538
#
# Generating signal for cad_oas_1yr_<lambda>:
# Signal True values: 2947
# Signal False values: 2544
#
# Generating signal for cad_oas_qtd_<lambda>:
# Signal True values: 3056
# Signal False values: 2435
#
# Generating signal for cad_oas_ytd_<lambda>:
# Signal True values: 3324
# Signal False values: 2167
#
# Generating signal for us_hy_oas_3m_<lambda>:
# Signal True values: 3370
# Signal False values: 2121
#
# Generating signal for us_hy_oas_1yr_<lambda>:
# Signal True values: 3247
# Signal False values: 2244
#
# Generating signal for us_hy_oas_qtd_<lambda>:
# Signal True values: 3496
# Signal False values: 1995
#
# Generating signal for us_hy_oas_ytd_<lambda>:
# Signal True values: 3491
# Signal False values: 2000
#
# Generating signal for us_ig_oas_3m_<lambda>:
# Signal True values: 3251
# Signal False values: 2240
#
# Generating signal for us_ig_oas_1yr_<lambda>:
# Signal True values: 3089
# Signal False values: 2402
#
# Generating signal for us_ig_oas_qtd_<lambda>:
# Signal True values: 3492
# Signal False values: 1999
#
# Generating signal for us_ig_oas_ytd_<lambda>:
# Signal True values: 3279
# Signal False values: 2212
#
# Generating signal for vix_3m_<lambda>:
# Signal True values: 3132
# Signal False values: 2359
#
# Generating signal for vix_1yr_<lambda>:
# Signal True values: 3030
# Signal False values: 2461
#
# Generating signal for vix_qtd_<lambda>:
# Signal True values: 3140
# Signal False values: 2351
#
# Generating signal for vix_ytd_<lambda>:
# Signal True values: 3158
# Signal False values: 2333
#
# Signal Generation Summary:
# Number of signals generated: 32
# Signal array shape: (32, 5491)
#
# Starting genetic algorithm optimization...
# Generation 0: Best Fitness = 0.8453, Overall Best = 0.8453
# Found good solution at generation 0
#
# Optimization completed.
#
# Processing portfolios...
#
# Processed Combined:us_hy_er_index_qtd_<lambda>:cad_oas_1yr_<lambda>:tsx_ytd_<lambda>:us_ig_oas_ytd_<lambda>:OR:OR:AND:
# Total Return: 57.32%
# Sharpe Ratio: 3.01
# Max Drawdown: -1.84%
#
# Processed Combined:us_ig_er_index_3m_<lambda>:cad_oas_qtd_<lambda>:OR:
# Total Return: 74.38%
# Sharpe Ratio: 3.10
# Max Drawdown: -1.90%
#
# Processed Combined:cad_oas_3m_<lambda>:cad_ig_er_index_3m_<lambda>:OR:
# Total Return: 55.67%
# Sharpe Ratio: 2.89
# Max Drawdown: -1.60%
#
# Processed Combined:cad_oas_qtd_<lambda>:us_ig_oas_ytd_<lambda>:OR:
# Total Return: 72.75%
# Sharpe Ratio: 3.05
# Max Drawdown: -1.84%
#
# Processed Combined:vix_1yr_<lambda>:us_hy_er_index_3m_<lambda>:AND:
# Total Return: 36.77%
# Sharpe Ratio: 2.98
# Max Drawdown: -1.73%
#
# Processed Combined:cad_oas_qtd_<lambda>:cad_ig_er_index_ytd_<lambda>:cad_ig_er_index_3m_<lambda>:vix_3m_<lambda>:tsx_qtd_<lambda>:OR:AND:OR:AND:
# Total Return: 67.92%
# Sharpe Ratio: 3.56
# Max Drawdown: -1.84%
#
# Processed Combined:cad_oas_qtd_<lambda>:cad_ig_er_index_ytd_<lambda>:us_hy_er_index_1yr_<lambda>:tsx_3m_<lambda>:vix_3m_<lambda>:vix_ytd_<lambda>:us_ig_er_index_ytd_<lambda>:cad_oas_1yr_<lambda>:us_hy_oas_qtd_<lambda>:OR:AND:OR:AND:AND:AND:AND:AND:
# Total Return: 17.45%
# Sharpe Ratio: 2.63
# Max Drawdown: -0.65%
#
# Processed Combined:us_ig_oas_qtd_<lambda>:us_hy_oas_3m_<lambda>:cad_ig_er_index_1yr_<lambda>:OR:AND:
# Total Return: 64.66%
# Sharpe Ratio: 3.29
# Max Drawdown: -1.84%
#
# Processed Combined:cad_oas_3m_<lambda>:cad_oas_qtd_<lambda>:us_hy_oas_3m_<lambda>:us_hy_er_index_1yr_<lambda>:us_ig_er_index_qtd_<lambda>:us_ig_oas_ytd_<lambda>:tsx_3m_<lambda>:us_hy_oas_qtd_<lambda>:us_hy_er_index_qtd_<lambda>:us_ig_er_index_ytd_<lambda>:cad_oas_1yr_<lambda>:tsx_ytd_<lambda>:AND:AND:AND:OR:AND:AND:AND:OR:AND:AND:OR:
# Total Return: 64.97%
# Sharpe Ratio: 3.13
# Max Drawdown: -1.84%
#
# Processed Combined:us_hy_er_index_ytd_<lambda>:vix_qtd_<lambda>:us_ig_er_index_3m_<lambda>:tsx_3m_<lambda>:AND:AND:AND:
# Total Return: 45.94%
# Sharpe Ratio: 3.38
# Max Drawdown: -0.55%
#
# Processed Combined:cad_oas_3m_<lambda>:cad_ig_er_index_ytd_<lambda>:vix_qtd_<lambda>:cad_ig_er_index_1yr_<lambda>:cad_ig_er_index_qtd_<lambda>:us_ig_oas_qtd_<lambda>:us_ig_oas_1yr_<lambda>:tsx_3m_<lambda>:vix_ytd_<lambda>:tsx_1yr_<lambda>:us_hy_oas_1yr_<lambda>:us_ig_er_index_ytd_<lambda>:cad_oas_1yr_<lambda>:AND:AND:AND:AND:AND:OR:AND:AND:AND:OR:AND:OR:
# Total Return: 83.22%
# Sharpe Ratio: 3.64
# Max Drawdown: -1.70%
#
# Processed Combined:vix_1yr_<lambda>:vix_3m_<lambda>:cad_ig_er_index_1yr_<lambda>:cad_ig_er_index_qtd_<lambda>:OR:AND:OR:
# Total Return: 72.39%
# Sharpe Ratio: 3.30
# Max Drawdown: -1.84%
#
# Processed Combined:cad_oas_3m_<lambda>:us_ig_oas_3m_<lambda>:cad_oas_qtd_<lambda>:cad_ig_er_index_1yr_<lambda>:vix_1yr_<lambda>:us_hy_er_index_3m_<lambda>:us_hy_oas_1yr_<lambda>:us_ig_er_index_1yr_<lambda>:cad_oas_1yr_<lambda>:tsx_ytd_<lambda>:OR:OR:OR:OR:OR:AND:AND:OR:AND:
# Total Return: 33.68%
# Sharpe Ratio: 2.81
# Max Drawdown: -1.59%
#
# Processed Combined:us_ig_er_index_qtd_<lambda>:vix_qtd_<lambda>:cad_ig_er_index_3m_<lambda>:AND:OR:
# Total Return: 82.88%
# Sharpe Ratio: 3.57
# Max Drawdown: -1.88%
#
# Processed Combined:us_hy_er_index_ytd_<lambda>:us_hy_oas_1yr_<lambda>:cad_ig_er_index_1yr_<lambda>:us_ig_oas_ytd_<lambda>:AND:OR:AND:
# Total Return: 33.17%
# Sharpe Ratio: 2.48
# Max Drawdown: -1.83%
#
# Processed Combined:us_ig_oas_3m_<lambda>:us_hy_oas_ytd_<lambda>:cad_ig_er_index_ytd_<lambda>:us_hy_er_index_1yr_<lambda>:us_ig_er_index_qtd_<lambda>:cad_ig_er_index_3m_<lambda>:tsx_3m_<lambda>:vix_1yr_<lambda>:us_ig_er_index_1yr_<lambda>:tsx_ytd_<lambda>:AND:AND:AND:AND:AND:AND:AND:AND:OR:
# Total Return: 41.95%
# Sharpe Ratio: 2.86
# Max Drawdown: -1.64%
#
# Processed Combined:tsx_qtd_<lambda>:us_ig_er_index_qtd_<lambda>:cad_oas_1yr_<lambda>:cad_oas_ytd_<lambda>:AND:OR:AND:
# Total Return: 53.56%
# Sharpe Ratio: 3.23
# Max Drawdown: -1.68%
#
# Processed Combined:us_ig_er_index_3m_<lambda>:us_hy_oas_ytd_<lambda>:us_hy_er_index_3m_<lambda>:OR:OR:
# Total Return: 69.92%
# Sharpe Ratio: 3.12
# Max Drawdown: -2.29%
#
# Processed Combined:us_ig_er_index_ytd_<lambda>:cad_oas_1yr_<lambda>:vix_ytd_<lambda>:cad_oas_3m_<lambda>:AND:AND:AND:
# Total Return: 21.99%
# Sharpe Ratio: 2.65
# Max Drawdown: -1.00%
#
# Processed Combined:tsx_ytd_<lambda>:us_ig_oas_qtd_<lambda>:us_hy_er_index_1yr_<lambda>:AND:OR:
# Total Return: 82.98%
# Sharpe Ratio: 3.25
# Max Drawdown: -2.29%
#
# Processed Combined:us_ig_er_index_ytd_<lambda>:cad_oas_1yr_<lambda>:us_ig_oas_1yr_<lambda>:AND:OR:
# Total Return: 32.68%
# Sharpe Ratio: 2.25
# Max Drawdown: -2.40%
#
# Processed Combined:us_hy_er_index_ytd_<lambda>:us_hy_oas_qtd_<lambda>:us_hy_er_index_3m_<lambda>:AND:OR:
# Total Return: 83.62%
# Sharpe Ratio: 3.37
# Max Drawdown: -1.84%
#
# Processed Combined:us_hy_er_index_qtd_<lambda>:us_hy_oas_qtd_<lambda>:us_hy_er_index_3m_<lambda>:AND:OR:
# Total Return: 83.13%
# Sharpe Ratio: 3.42
# Max Drawdown: -1.84%
#
# Processed Combined:us_hy_oas_ytd_<lambda>:us_hy_oas_3m_<lambda>:vix_3m_<lambda>:AND:OR:
# Total Return: 72.33%
# Sharpe Ratio: 3.28
# Max Drawdown: -2.07%
#
# Processed Combined:us_hy_oas_qtd_<lambda>:us_hy_er_index_3m_<lambda>:cad_ig_er_index_qtd_<lambda>:AND:AND:
# Total Return: 56.40%
# Sharpe Ratio: 3.22
# Max Drawdown: -1.76%
#
# Processed Combined:vix_qtd_<lambda>:cad_oas_1yr_<lambda>:us_ig_oas_1yr_<lambda>:tsx_1yr_<lambda>:AND:OR:OR:
# Total Return: 76.15%
# Sharpe Ratio: 3.10
# Max Drawdown: -2.40%
#
# Processed Combined:us_ig_er_index_ytd_<lambda>:vix_qtd_<lambda>:cad_ig_er_index_qtd_<lambda>:AND:AND:
# Total Return: 49.89%
# Sharpe Ratio: 3.49
# Max Drawdown: -0.88%
#
# Processed Combined:us_ig_oas_3m_<lambda>:cad_ig_er_index_1yr_<lambda>:cad_ig_er_index_qtd_<lambda>:cad_ig_er_index_3m_<lambda>:us_ig_oas_ytd_<lambda>:us_hy_er_index_ytd_<lambda>:vix_ytd_<lambda>:tsx_1yr_<lambda>:us_hy_oas_1yr_<lambda>:us_ig_er_index_1yr_<lambda>:cad_oas_1yr_<lambda>:vix_1yr_<lambda>:us_ig_er_index_ytd_<lambda>:AND:AND:OR:AND:AND:AND:AND:AND:AND:OR:AND:AND:
# Total Return: 33.90%
# Sharpe Ratio: 3.08
# Max Drawdown: -0.94%
#
# Processed Combined:cad_oas_1yr_<lambda>:cad_oas_ytd_<lambda>:vix_3m_<lambda>:AND:OR:
# Total Return: 71.47%
# Sharpe Ratio: 3.24
# Max Drawdown: -2.13%
#
# Processed Combined:vix_qtd_<lambda>:cad_ig_er_index_1yr_<lambda>:tsx_ytd_<lambda>:us_ig_er_index_ytd_<lambda>:vix_1yr_<lambda>:OR:AND:OR:OR:
# Total Return: 80.25%
# Sharpe Ratio: 3.19
# Max Drawdown: -2.19%
#
# Processed Combined:us_ig_er_index_ytd_<lambda>:us_hy_er_index_3m_<lambda>:OR:
# Total Return: 68.36%
# Sharpe Ratio: 3.04
# Max Drawdown: -2.06%
#
# Processed Combined:vix_qtd_<lambda>:cad_ig_er_index_3m_<lambda>:AND:
# Total Return: 55.03%
# Sharpe Ratio: 3.48
# Max Drawdown: -0.99%
#
# Processed Combined:us_hy_oas_3m_<lambda>:us_hy_er_index_1yr_<lambda>:us_ig_oas_1yr_<lambda>:us_ig_er_index_3m_<lambda>:us_ig_er_index_ytd_<lambda>:OR:AND:AND:AND:
# Total Return: 31.10%
# Sharpe Ratio: 2.71
# Max Drawdown: -1.69%
#
# Processed Combined:us_ig_oas_3m_<lambda>:cad_ig_er_index_ytd_<lambda>:vix_qtd_<lambda>:us_ig_oas_qtd_<lambda>:us_hy_oas_qtd_<lambda>:us_hy_er_index_qtd_<lambda>:us_hy_er_index_3m_<lambda>:vix_3m_<lambda>:us_ig_er_index_3m_<lambda>:tsx_ytd_<lambda>:AND:OR:AND:AND:AND:AND:OR:AND:OR:
# Total Return: 84.53%
# Sharpe Ratio: 3.51
# Max Drawdown: -1.84%
#
# Processed Combined:vix_1yr_<lambda>:tsx_1yr_<lambda>:OR:
# Total Return: 27.13%
# Sharpe Ratio: 1.34
# Max Drawdown: -6.89%
#
# Processed Combined:cad_oas_3m_<lambda>:us_hy_oas_ytd_<lambda>:cad_ig_er_index_qtd_<lambda>:cad_ig_er_index_3m_<lambda>:us_ig_oas_ytd_<lambda>:cad_oas_ytd_<lambda>:us_hy_er_index_3m_<lambda>:us_ig_er_index_3m_<lambda>:us_hy_oas_qtd_<lambda>:AND:AND:OR:AND:OR:OR:AND:OR:
# Total Return: 59.25%
# Sharpe Ratio: 2.96
# Max Drawdown: -1.84%
#
# Processed Combined:cad_oas_3m_<lambda>:cad_oas_qtd_<lambda>:cad_ig_er_index_ytd_<lambda>:us_hy_oas_3m_<lambda>:cad_ig_er_index_1yr_<lambda>:cad_ig_er_index_3m_<lambda>:tsx_3m_<lambda>:us_hy_er_index_qtd_<lambda>:us_hy_er_index_3m_<lambda>:us_ig_er_index_1yr_<lambda>:cad_oas_1yr_<lambda>:vix_1yr_<lambda>:us_ig_er_index_ytd_<lambda>:AND:OR:AND:AND:AND:AND:OR:AND:OR:AND:AND:AND:
# Total Return: 26.62%
# Sharpe Ratio: 3.07
# Max Drawdown: -0.74%
#
# Processed Combined:vix_qtd_<lambda>:us_hy_er_index_3m_<lambda>:us_hy_er_index_1yr_<lambda>:AND:OR:
# Total Return: 82.60%
# Sharpe Ratio: 3.48
# Max Drawdown: -2.14%
#
# Processed Combined:us_ig_er_index_ytd_<lambda>:us_ig_oas_1yr_<lambda>:OR:
# Total Return: 57.14%
# Sharpe Ratio: 2.75
# Max Drawdown: -2.40%
#
# Processed Combined:us_hy_er_index_ytd_<lambda>:us_hy_er_index_qtd_<lambda>:us_hy_oas_3m_<lambda>:AND:AND:
# Total Return: 53.94%
# Sharpe Ratio: 3.08
# Max Drawdown: -1.84%
#
# Processed Combined:us_ig_er_index_qtd_<lambda>:us_ig_oas_qtd_<lambda>:AND:
# Total Return: 78.82%
# Sharpe Ratio: 3.37
# Max Drawdown: -1.84%
#
# Processed Combined:us_ig_oas_3m_<lambda>:cad_oas_qtd_<lambda>:us_ig_er_index_qtd_<lambda>:cad_oas_ytd_<lambda>:us_ig_er_index_1yr_<lambda>:cad_oas_1yr_<lambda>:AND:AND:OR:AND:OR:
# Total Return: 66.34%
# Sharpe Ratio: 3.13
# Max Drawdown: -2.22%
#
# Processed Combined:us_hy_oas_3m_<lambda>:cad_oas_ytd_<lambda>:tsx_qtd_<lambda>:cad_oas_1yr_<lambda>:vix_1yr_<lambda>:AND:AND:AND:AND:
# Total Return: 20.72%
# Sharpe Ratio: 2.93
# Max Drawdown: -1.06%
#
# Processed Combined:cad_oas_3m_<lambda>:us_hy_oas_1yr_<lambda>:AND:
# Total Return: 25.51%
# Sharpe Ratio: 2.50
# Max Drawdown: -0.83%
#
# Processed Combined:us_hy_er_index_ytd_<lambda>:us_ig_er_index_qtd_<lambda>:vix_ytd_<lambda>:cad_oas_3m_<lambda>:OR:AND:AND:
# Total Return: 43.39%
# Sharpe Ratio: 3.11
# Max Drawdown: -0.83%
#
# Processed Combined:cad_oas_ytd_<lambda>:us_ig_oas_ytd_<lambda>:AND:
# Total Return: 53.59%
# Sharpe Ratio: 2.97
# Max Drawdown: -1.84%
#
# Top 10 Strategies Overall:
#                                              Strategy  Total_Return_%  \
# 33  Combined:us_ig_oas_3m_<lambda>:cad_ig_er_index...       84.532576
# 21  Combined:us_hy_er_index_ytd_<lambda>:us_hy_oas...       83.620753
# 10  Combined:cad_oas_3m_<lambda>:cad_ig_er_index_y...       83.217247
# 22  Combined:us_hy_er_index_qtd_<lambda>:us_hy_oas...       83.134167
# 19  Combined:tsx_ytd_<lambda>:us_ig_oas_qtd_<lambd...       82.981185
# 13  Combined:us_ig_er_index_qtd_<lambda>:vix_qtd_<...       82.884321
# 37  Combined:vix_qtd_<lambda>:us_hy_er_index_3m_<l...       82.599141
# 29  Combined:vix_qtd_<lambda>:cad_ig_er_index_1yr_...       80.251346
# 40  Combined:us_ig_er_index_qtd_<lambda>:us_ig_oas...       78.822289
# 25  Combined:vix_qtd_<lambda>:cad_oas_1yr_<lambda>...       76.149039
#
#     Sharpe_Ratio  Max_Drawdown_%
# 33      3.510169       -1.839838
# 21      3.369471       -1.839838
# 10      3.640086       -1.699240
# 22      3.415262       -1.839838
# 19      3.247708       -2.293379
# 13      3.565674       -1.883936
# 37      3.482269       -2.139842
# 29      3.192951       -2.185424
# 40      3.372534       -1.839838
# 25      3.099589       -2.402191
#
# Best Strategy: Combined:us_ig_oas_3m_<lambda>:cad_ig_er_index_ytd_<lambda>:vix_qtd_<lambda>:us_ig_oas_qtd_<lambda>:us_hy_oas_qtd_<lambda>:us_hy_er_index_qtd_<lambda>:us_hy_er_index_3m_<lambda>:vix_3m_<lambda>:us_ig_er_index_3m_<lambda>:tsx_ytd_<lambda>:AND:OR:AND:AND:AND:AND:OR:AND:OR
#
# Best Strategy Performance:
# Total Return: 84.53%
# Sharpe Ratio: 3.51
# Max Drawdown: -1.84%
#
# Buy & Hold Performance:
# Total Return: 31.87%
# Sharpe Ratio: 1.03
# Max Drawdown: -15.48%
#
# Best Strategy Signal Composition:
# Signals used: ['cad_ig_er_index_ytd_<lambda>', 'us_hy_er_index_3m_<lambda>', 'us_hy_er_index_qtd_<lambda>', 'us_ig_er_index_3m_<lambda>', 'tsx_ytd_<lambda>', 'us_hy_oas_qtd_<lambda>', 'us_ig_oas_3m_<lambda>', 'us_ig_oas_qtd_<lambda>', 'vix_3m_<lambda>', 'vix_qtd_<lambda>']
